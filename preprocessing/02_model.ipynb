# %%
import sys
import os


sys.path.append(os.path.abspath(".."))

# %%
from src.utils import data_load

datasets = data_load.load_datasets()

# %%
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Js2P2OX65L0mfWRv63g7z-XAv30fHl7r
# To: /var/folders/hb/n_q78zrx4h72f7qw8pjwrwx80000gn/T/tmpd4w2u44q/file.csv
# 100%|██████████| 9.03M/9.03M [00:00<00:00, 11.3MB/s]
# ✅ Archivo cargado → 99441 filas, 5 columnas
# Downloading...
# From: https://drive.google.com/uc?id=1QNWrPqOn3Cxbj0qyOzm6p4Dsqp5SDyyg
# To: /var/folders/hb/n_q78zrx4h72f7qw8pjwrwx80000gn/T/tmpt6y86j7u/file.csv
# 100%|██████████| 175k/175k [00:00<00:00, 2.32MB/s]
# ✅ Archivo cargado → 3095 filas, 4 columnas
# Downloading...
# From: https://drive.google.com/uc?id=14pNzmp4Efr0NBJyCATceyDkRW_XzvTLQ
# To: /var/folders/hb/n_q78zrx4h72f7qw8pjwrwx80000gn/T/tmpo379ymhi/file.csv
# 100%|██████████| 61.3M/61.3M [00:02<00:00, 26.7MB/s]
# ✅ Archivo cargado → 1000163 filas, 5 columnas
# Downloading...
# From: https://drive.google.com/uc?id=1jLHg1ePMZw9tZ1S_b8JZBjTlSWzpTRU-
# To: /var/folders/hb/n_q78zrx4h72f7qw8pjwrwx80000gn/T/tmpm2p7atd1/file.csv
# ...

# %%
df_complete = df_orders.merge(df_customer, on='customer_id', how='left')
df_complete = df_complete.merge(df_order_items, left_on='order_id', right_on='order_id', how='left')
df_complete = df_complete.merge(df_products, left_on='product_id', right_on='product_id', how='left')
df_complete = df_complete.merge(df_categories, left_on='product_category_name', right_on='product_category_name', how='left')
df_complete = df_complete.merge(df_order_payments, left_on='order_id', right_on='order_id', how='left')
df_complete = df_complete.merge(df_reviews, left_on='order_id', right_on='order_id', how='left')
df_complete = df_complete.merge(df_seller, left_on='seller_id', right_on='seller_id', how='left')
df_complete.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
import pandas as pd
from deep_translator import GoogleTranslator

traductor = GoogleTranslator(source='auto', target='en')
df_test = df_complete.head(10)


df_test['english_review'] = df_test['review_comment_message'].apply(
    lambda x: traductor.translate(x) if isinstance(x, str) else x
)


print(df_test[['review_comment_message', 'english_review']])
# Out:
#                               review_comment_message  \
# 0  Não testei o produto ainda, mas ele veio corre...
# 1  Não testei o produto ainda, mas ele veio corre...
# 2  Não testei o produto ainda, mas ele veio corre...
# 3                               Muito bom o produto.
# 4                                                NaN
# 5  O produto foi exatamente o que eu esperava e e...
# 6                                                NaN
# 7                                                NaN
# 8               fiquei triste por n ter me atendido.
# 9                                                NaN
#
#                                       english_review
# 0  I haven't tested the product yet, but it arriv...
# 1  I haven't tested the product yet, but it arriv...
# 2  I haven't tested the product yet, but it arriv...
# 3                                 Very good product.
# 4                                                NaN
# 5  The product was exactly what I expected and wa...
# ...
